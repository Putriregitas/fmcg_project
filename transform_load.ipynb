# %%
import pandas as pd
from google.cloud import storage
from io import BytesIO
import os
import re

# %% [markdown]
# ### READ DATA FROM GCS

# %% [markdown]
# #### auto detect ingest date

# %%
def get_latest_ingest_date(bucket_name, dataset_name):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    prefix = f"raw/{dataset_name}/ingest_date="
    dates = {
        blob.name.split("ingest_date=")[1].split("/")[0]
        for blob in bucket.list_blobs(prefix=prefix)}
    return max(dates)

# %% [markdown]
# #### read raw data from gcs

# %%
def read_raw_from_gcs(
    bucket_name: str,
    dataset_name: str,
    ingest_date: str | None = None
):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    if ingest_date is None:
        ingest_date = get_latest_ingest_date(
            bucket_name, dataset_name)
    file_name = f"raw_{dataset_name}.csv"
    gcs_path = (
        f"raw/{dataset_name}/"
        f"ingest_date={ingest_date}/"
        f"{file_name}")
    blob = bucket.blob(gcs_path)
    data = blob.download_as_bytes()
    if data.startswith(b"<!DOCTYPE html"):
        raise ValueError("RAW file is HTML")
    df = pd.read_csv(BytesIO(data), engine="python")
    print(f"Loaded {dataset_name} (ingest_date={ingest_date})")
    return df

# %%
BUCKET_NAME = "fmcg-data-lake"

df_sales = read_raw_from_gcs(
    BUCKET_NAME, "sales_transaction")
df_inventory_outlet = read_raw_from_gcs(
    BUCKET_NAME, "inventory_outlet_daily")
df_inventory_warehouse = read_raw_from_gcs(
    BUCKET_NAME, "inventory_warehouse_daily")
df_outlet = read_raw_from_gcs(
    BUCKET_NAME, "outlet_master")
df_product = read_raw_from_gcs(
    BUCKET_NAME, "product_master")
# Out:
# Loaded sales_transaction (ingest_date=2026-01-20)
# Loaded inventory_outlet_daily (ingest_date=2026-01-20)
# Loaded inventory_warehouse_daily (ingest_date=2026-01-20)
# Loaded outlet_master (ingest_date=2026-01-20)
# Loaded product_master (ingest_date=2026-01-20)

# %% [markdown]
# ### TRANSFORM/CLEANING

# %% [markdown]
# #### PRODUCT MASTER

# %% [markdown]
# ##### EDA

# %%
def data_quality_overview(df: pd.DataFrame) -> pd.DataFrame:
    summary = pd.DataFrame({
        "data_type": df.dtypes,
        "total_rows": len(df),
        "null_count": df.isnull().sum(),
        "null_pct": (df.isnull().sum() / len(df) * 100).round(2),
        "unique_count": df.nunique()})
    return summary.sort_values("null_pct", ascending=False)

# %%
data_quality_overview(df_product)
# Out:
#              data_type  total_rows  null_count  null_pct  unique_count
# PackSize_ml     object          45          11     24.44             3
# SKU_CODE        object          45           0      0.00            45
# product_name    object          45           0      0.00            15
# Brand           object          45           0      0.00             3
# category        object          45           0      0.00             1
# sub_category    object          45           0      0.00             5

# %%
def value_counts_all_columns(df: pd.DataFrame):
    for col in df.columns:
        print(f"\n=== Value count: {col} ===")
        print(df[col].value_counts(dropna=False))

# %%
value_counts_all_columns(df_product)
# Out:
# === Value count: SKU_CODE ===
# SKU_CODE
# FW001    1
# FW002    1
# FW003    1
# SR004    1
# SR005    1
# SR006    1
# TN007    1
# TN008    1
# TN009    1
# MS010    1
# MS011    1
# MS012    1
# SS013    1
# SS014    1
# SS015    1
# FW016    1
# FW017    1
# FW018    1
# SR019    1
# SR020    1
# SR021    1
# TN022    1
# TN023    1
# TN024    1
# MS025    1
# MS026    1
# MS027    1
# SS028    1
# SS029    1
# SS030    1
# FW031    1
# FW032    1
# FW033    1
# SR034    1
# SR035    1
# SR036    1
# TN037    1
# TN038    1
# TN039    1
# MS040    1
# MS041    1
# MS042    1
# SS043    1
# SS044    1
# SS045    1
# Name: count, dtype: int64
#
# === Value count: product_name ===
# product_name
# Glowix Gentle Facial Wash          3
# Glowix Vitamin C Serum             3
# Glowix Hydrating Toner             3
# Glowix Daily Moisturizer           3
# Glowix SPF 50 Sunscreen            3
# DermaPlus Acne Defense Cleanser    3
# DermaPlus Retinol Night Serum      3
# DermaPlus Calming Toner            3
# DermaPlus Oil-Free Gel Cream       3
# DermaPlus UV Shield SPF 30         3
# Skinvera Bright Foam Cleanser      3
# Skinvera Niacinamide Booster       3
# Skinvera Pore Tightening Toner     3
# Skinvera Hydra Repair Cream        3
# Skinvera Daily Sun Gel SPF 35      3
# Name: count, dtype: int64
#
# === Value count: Brand  ===
# Brand
# Glowix       15
# DermaPlus    15
# Skinvera     15
# Name: count, dtype: int64
#
# === Value count: category ===
# category
# Skincare    45
# Name: count, dtype: int64
#
# === Value count: sub_category ===
# sub_category
# Cleanser       9
# Serum          9
# Toner          9
# Moisturizer    9
# Sunscreen      9
# Name: count, dtype: int64
#
# === Value count: PackSize_ml ===
# PackSize_ml
# 50ml      12
# 100 ML    12
# NaN       11
# 30 ml     10
# Name: count, dtype: int64

# %%
df_product[df_product.isnull().any(axis=1)]
# Out:
#    SKU_CODE                  product_name     Brand   category sub_category  \
# 3     SR004        Glowix Vitamin C Serum     Glowix  Skincare        Serum
# 6     TN007        Glowix Hydrating Toner     Glowix  Skincare        Toner
# 8     TN009        Glowix Hydrating Toner     Glowix  Skincare        Toner
# 10    MS011      Glowix Daily Moisturizer     Glowix  Skincare  Moisturizer
# 11    MS012      Glowix Daily Moisturizer     Glowix  Skincare  Moisturizer
# 14    SS015       Glowix SPF 50 Sunscreen     Glowix  Skincare    Sunscreen
# 21    TN022       DermaPlus Calming Toner  DermaPlus  Skincare        Toner
# 24    MS025  DermaPlus Oil-Free Gel Cream  DermaPlus  Skincare  Moisturizer
# 25    MS026  DermaPlus Oil-Free Gel Cream  DermaPlus  Skincare  Moisturizer
# 33    SR034  Skinvera Niacinamide Booster   Skinvera  Skincare        Serum
# 34    SR035  Skinvera Niacinamide Booster   Skinvera  Skincare        Serum
#
#    PackSize_ml
# 3          NaN
# 6          NaN
# 8          NaN
# 10         NaN
# 11         NaN
# 14         NaN
# 21         NaN
# 24         NaN
# 25         NaN
# 33         NaN
# 34         NaN

# %%
df_product
# Out:
#    SKU_CODE                     product_name     Brand   category  \
# 0     FW001        Glowix Gentle Facial Wash     Glowix  Skincare
# 1     FW002        Glowix Gentle Facial Wash     Glowix  Skincare
# 2     FW003        Glowix Gentle Facial Wash     Glowix  Skincare
# 3     SR004           Glowix Vitamin C Serum     Glowix  Skincare
# 4     SR005           Glowix Vitamin C Serum     Glowix  Skincare
# 5     SR006           Glowix Vitamin C Serum     Glowix  Skincare
# 6     TN007           Glowix Hydrating Toner     Glowix  Skincare
# 7     TN008           Glowix Hydrating Toner     Glowix  Skincare
# 8     TN009           Glowix Hydrating Toner     Glowix  Skincare
# 9     MS010         Glowix Daily Moisturizer     Glowix  Skincare
# 10    MS011         Glowix Daily Moisturizer     Glowix  Skincare
# 11    MS012         Glowix Daily Moisturizer     Glowix  Skincare
# 12    SS013          Glowix SPF 50 Sunscreen     Glowix  Skincare
# 13    SS014          Glowix SPF 50 Sunscreen     Glowix  Skincare
# 14    SS015          Glowix SPF 50 Sunscreen     Glowix  Skincare
# 15    FW016  DermaPlus Acne Defense Cleanser  DermaPlus  Skincare
# 16    FW017  DermaPlus Acne Defense Cleanser  DermaPlus  Skincare
# 17    FW018  DermaPlus Acne Defense Cleanser  DermaPlus  Skincare
# 18    SR019    DermaPlus Retinol Night Serum  DermaPlus  Skincare
# 19    SR020    DermaPlus Retinol Night Serum  DermaPlus  Skincare
# 20    SR021    DermaPlus Retinol Night Serum  DermaPlus  Skincare
# 21    TN022          DermaPlus Calming Toner  DermaPlus  Skincare
# 22    TN023          DermaPlus Calming Toner  DermaPlus  Skincare
# 23    TN024          DermaPlus Calming Toner  DermaPlus  Skincare
# 24    MS025     DermaPlus Oil-Free Gel Cream  DermaPlus  Skincare
# 25    MS026     DermaPlus Oil-Free Gel Cream  DermaPlus  Skincare
# 26    MS027     DermaPlus Oil-Free Gel Cream  DermaPlus  Skincare
# 27    SS028       DermaPlus UV Shield SPF 30  DermaPlus  Skincare
# 28    SS029       DermaPlus UV Shield SPF 30  DermaPlus  Skincare
# 29    SS030       DermaPlus UV Shield SPF 30  DermaPlus  Skincare
# 30    FW031    Skinvera Bright Foam Cleanser   Skinvera  Skincare
# 31    FW032    Skinvera Bright Foam Cleanser   Skinvera  Skincare
# 32    FW033    Skinvera Bright Foam Cleanser   Skinvera  Skincare
# 33    SR034     Skinvera Niacinamide Booster   Skinvera  Skincare
# 34    SR035     Skinvera Niacinamide Booster   Skinvera  Skincare
# 35    SR036     Skinvera Niacinamide Booster   Skinvera  Skincare
# 36    TN037   Skinvera Pore Tightening Toner   Skinvera  Skincare
# 37    TN038   Skinvera Pore Tightening Toner   Skinvera  Skincare
# 38    TN039   Skinvera Pore Tightening Toner   Skinvera  Skincare
# 39    MS040      Skinvera Hydra Repair Cream   Skinvera  Skincare
# 40    MS041      Skinvera Hydra Repair Cream   Skinvera  Skincare
# 41    MS042      Skinvera Hydra Repair Cream   Skinvera  Skincare
# 42    SS043    Skinvera Daily Sun Gel SPF 35   Skinvera  Skincare
# 43    SS044    Skinvera Daily Sun Gel SPF 35   Skinvera  Skincare
# 44    SS045    Skinvera Daily Sun Gel SPF 35   Skinvera  Skincare
#
#    sub_category PackSize_ml
# 0      Cleanser       30 ml
# 1      Cleanser        50ml
# 2      Cleanser      100 ML
# 3         Serum         NaN
# 4         Serum        50ml
# 5         Serum      100 ML
# 6         Toner         NaN
# 7         Toner        50ml
# 8         Toner         NaN
# 9   Moisturizer       30 ml
# 10  Moisturizer         NaN
# 11  Moisturizer         NaN
# 12    Sunscreen       30 ml
# 13    Sunscreen        50ml
# 14    Sunscreen         NaN
# 15     Cleanser       30 ml
# 16     Cleanser        50ml
# 17     Cleanser      100 ML
# 18        Serum       30 ml
# 19        Serum        50ml
# 20        Serum      100 ML
# 21        Toner         NaN
# 22        Toner        50ml
# 23        Toner      100 ML
# 24  Moisturizer         NaN
# 25  Moisturizer         NaN
# 26  Moisturizer      100 ML
# 27    Sunscreen       30 ml
# 28    Sunscreen        50ml
# 29    Sunscreen      100 ML
# 30     Cleanser       30 ml
# 31     Cleanser        50ml
# 32     Cleanser      100 ML
# 33        Serum         NaN
# 34        Serum         NaN
# 35        Serum      100 ML
# 36        Toner       30 ml
# 37        Toner        50ml
# 38        Toner      100 ML
# 39  Moisturizer       30 ml
# 40  Moisturizer        50ml
# 41  Moisturizer      100 ML
# 42    Sunscreen       30 ml
# 43    Sunscreen        50ml
# 44    Sunscreen      100 ML

# %% [markdown]
# ##### CLEANING/TRANSFORM

# %% [markdown]
# Standardisasi kolom & extract pack size

# %%
def extract_pack_size_ml(x):
    if pd.isna(x):
        return None
    match = re.search(r"\d+", str(x))
    return int(match.group()) if match else None

df_product["pack_size_ml"] = df_product["PackSize_ml"].apply(extract_pack_size_ml)

# %%
df_product[["PackSize_ml", "pack_size_ml"]].drop_duplicates()
# Out:
#   PackSize_ml  pack_size_ml
# 0       30 ml          30.0
# 1        50ml          50.0
# 2      100 ML         100.0
# 3         NaN           NaN

# %%
DEFAULT_PACK_SIZES = [30, 50, 100]

def fill_pack_size(df):
    df = df.copy()
    df["pack_size_source"] = "original"
    for product, group in df.groupby("product_name"):
        existing_sizes = sorted(
            group["pack_size_ml"].dropna().unique().tolist())
        missing_idx = group[group["pack_size_ml"].isna()].index
        available_sizes = [
            s for s in DEFAULT_PACK_SIZES
            if s not in existing_sizes]
        for i, idx in enumerate(missing_idx):
            if i < len(available_sizes):
                df.loc[idx, "pack_size_ml"] = available_sizes[i]
                df.loc[idx, "pack_size_source"] = "assumption"
    return df

# %%
df_product = fill_pack_size(df_product)
df_product.head()
# Out:
#   SKU_CODE               product_name  Brand   category sub_category  \
# 0    FW001  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 1    FW002  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 2    FW003  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 3    SR004     Glowix Vitamin C Serum  Glowix  Skincare        Serum
# 4    SR005     Glowix Vitamin C Serum  Glowix  Skincare        Serum
#
#   PackSize_ml  pack_size_ml pack_size_source
# 0       30 ml          30.0         original
# 1        50ml          50.0         original
# 2      100 ML         100.0         original
# 3         NaN          30.0       assumption
# 4        50ml          50.0         original

# %%
def standardize_product(df):
    df = df.copy()
    df = df.rename(columns={
        "SKU_CODE": "sku_id",
        "Brand ": "brand",
    })
    return df

# %%
df_product_clean = standardize_product(df_product)
df_product_clean.head()
# Out:
#   sku_id               product_name   brand  category sub_category  \
# 0  FW001  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 1  FW002  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 2  FW003  Glowix Gentle Facial Wash  Glowix  Skincare     Cleanser
# 3  SR004     Glowix Vitamin C Serum  Glowix  Skincare        Serum
# 4  SR005     Glowix Vitamin C Serum  Glowix  Skincare        Serum
#
#   PackSize_ml  pack_size_ml pack_size_source
# 0       30 ml          30.0         original
# 1        50ml          50.0         original
# 2      100 ML         100.0         original
# 3         NaN          30.0       assumption
# 4        50ml          50.0         original

# %% [markdown]
# #### OUTLET MASTER

# %% [markdown]
# ##### EDA

# %%
data_quality_overview(df_outlet)
# Out:
#            data_type  total_rows  null_count  null_pct  unique_count
# outlet_id     object          25           0       0.0            25
# OutletName    object          25           0       0.0            25
# CHANNEL       object          25           0       0.0             4
# Region        object          25           0       0.0             4
# city_name     object          25           0       0.0             4

# %%
value_counts_all_columns(df_outlet)
# Out:
# === Value count: outlet_id ===
# outlet_id
# OUT-001    1
# OUT-002    1
# OUT-003    1
# OUT-004    1
# OUT-005    1
# OUT-006    1
# OUT-007    1
# OUT-008    1
# OUT-009    1
# OUT-010    1
# OUT-011    1
# OUT-012    1
# OUT-013    1
# OUT-014    1
# OUT-015    1
# OUT-016    1
# OUT-017    1
# OUT-018    1
# OUT-019    1
# OUT-020    1
# OUT-021    1
# OUT-022    1
# OUT-023    1
# OUT-024    1
# OUT-025    1
# Name: count, dtype: int64
#
# === Value count: OutletName ===
# OutletName
# Guardian Sudirman               1
# Toko Kosmetik Cantika Tebet     1
# Guardian Dago                   1
# Watsons Grand Indonesia         1
# Toko Kosmetik Ayu Margonda      1
# Guardian Bekasi Barat           1
# Toko Kosmetik Indah Bogor       1
# Watsons Central Park            1
# Guardian Alam Sutera            1
# Toko Kosmetik Ratu Karawaci     1
# Guardian Tunjungan Plaza        1
# Watsons Pakuwon Mall            1
# Toko Kosmetik Sari Malang       1
# Guardian Simpang Lima           1
# Toko Kosmetik Putri Solo        1
# Watsons Trans Studio Mall       1
# Guardian Malioboro              1
# Toko Kosmetik Laras Sleman      1
# Guardian Purwokerto             1
# Watsons PVJ Bandung             1
# Toko Kosmetik Cantik Cirebon    1
# Guardian Tasikmalaya            1
# Toko Kosmetik Ayu Sukabumi      1
# Watsons Galaxy Mall             1
# Guardian Jember                 1
# Name: count, dtype: int64
#
# === Value count: CHANNEL ===
# CHANNEL
# modern trade    9
# GT              7
# gt              6
# MT              3
# Name: count, dtype: int64
#
# === Value count: Region  ===
# Region
# Jakarta Area    9
# East Java       6
# Central Java    6
# West Java       4
# Name: count, dtype: int64
#
# === Value count: city_name ===
# city_name
# Surabaya    10
# Jakarta      8
# Bandung      5
# Semarang     2
# Name: count, dtype: int64

# %% [markdown]
# ##### CLEANING/TRANSFORM

# %%
def transform_outlet_master(df_raw: pd.DataFrame) -> pd.DataFrame:
    df = df_raw.copy()
    # standardize column names (strip spasi saja dulu)
    df.columns = df.columns.str.strip()
    # rename kolom ke snake_case
    df = df.rename(columns={
        "OutletName": "outlet_name",
        "CHANNEL": "channel",
        "Region": "region"})
    # standardize text fields
    df["outlet_name"] = df["outlet_name"].str.title()
    df["city_name"] = df["city_name"].str.title()
    df["region"] = df["region"].str.title()
    # normalize channel
    channel_map = {
        "gt": "GT",
        "modern trade" : "MT"}
    df["channel"] = (
        df["channel"]
        .str.lower()
        .map(channel_map)
        .fillna(df["channel"]))
    # deduplicate outlet_id
    df = df.drop_duplicates(subset=["outlet_id"])
    return df

# %%
df_outlet_clean = transform_outlet_master(df_outlet)
df_outlet_clean
# Out:
#    outlet_id                   outlet_name channel        region city_name
# 0    OUT-001             Guardian Sudirman      MT  Jakarta Area   Bandung
# 1    OUT-002   Toko Kosmetik Cantika Tebet      GT     East Java  Surabaya
# 2    OUT-003                 Guardian Dago      MT     East Java  Surabaya
# 3    OUT-004       Watsons Grand Indonesia      GT  Central Java  Surabaya
# 4    OUT-005    Toko Kosmetik Ayu Margonda      MT  Central Java   Jakarta
# 5    OUT-006         Guardian Bekasi Barat      MT     East Java  Surabaya
# 6    OUT-007     Toko Kosmetik Indah Bogor      MT  Jakarta Area   Jakarta
# 7    OUT-008          Watsons Central Park      MT  Jakarta Area   Bandung
# 8    OUT-009          Guardian Alam Sutera      GT     East Java   Jakarta
# 9    OUT-010   Toko Kosmetik Ratu Karawaci      MT     West Java   Jakarta
# 10   OUT-011      Guardian Tunjungan Plaza      GT  Jakarta Area  Semarang
# 11   OUT-012          Watsons Pakuwon Mall      MT  Jakarta Area  Surabaya
# 12   OUT-013     Toko Kosmetik Sari Malang      GT     East Java   Bandung
# 13   OUT-014         Guardian Simpang Lima      MT     West Java   Jakarta
# 14   OUT-015      Toko Kosmetik Putri Solo      GT  Jakarta Area   Jakarta
# 15   OUT-016     Watsons Trans Studio Mall      GT     East Java   Jakarta
# 16   OUT-017            Guardian Malioboro      GT     West Java  Surabaya
# 17   OUT-018    Toko Kosmetik Laras Sleman      GT  Jakarta Area  Surabaya
# 18   OUT-019           Guardian Purwokerto      MT  Central Java  Semarang
# 19   OUT-020           Watsons Pvj Bandung      GT  Jakarta Area   Bandung
# 20   OUT-021  Toko Kosmetik Cantik Cirebon      GT     West Java  Surabaya
# 21   OUT-022          Guardian Tasikmalaya      GT  Central Java   Jakarta
# 22   OUT-023    Toko Kosmetik Ayu Sukabumi      MT  Central Java   Bandung
# 23   OUT-024           Watsons Galaxy Mall      MT  Jakarta Area  Surabaya
# 24   OUT-025               Guardian Jember      GT  Central Java  Surabaya

# %% [markdown]
# #### INVENTORY OUTLET DAILY

# %% [markdown]
# ##### EDA

# %%
data_quality_overview(df_inventory_outlet)
# Out:
#               data_type  total_rows  null_count  null_pct  unique_count
# end_stock       float64      101250       33650     33.23            31
# stock_in        float64      101250       20471     20.22             4
# snapshot_date    object      101250           0      0.00            90
# outlet_id        object      101250           0      0.00            25
# sku_code         object      101250           0      0.00            45

# %%
value_counts_all_columns(df_inventory_outlet)
# Out:
# === Value count: snapshot_date ===
# snapshot_date
# 2024-01-01    1125
# 2024-01-02    1125
# 2024-01-03    1125
# 2024-01-04    1125
# 2024-01-05    1125
#               ...
# 2024-03-26    1125
# 2024-03-27    1125
# 2024-03-28    1125
# 2024-03-29    1125
# 2024-03-30    1125
# Name: count, Length: 90, dtype: int64
#
# === Value count: sku_code ===
# sku_code
# FW001    2250
# FW002    2250
# FW003    2250
# SR004    2250
# SR005    2250
# SR006    2250
# TN007    2250
# TN008    2250
# TN009    2250
# MS010    2250
# MS011    2250
# MS012    2250
# SS013    2250
# SS014    2250
# SS015    2250
# FW016    2250
# FW017    2250
# FW018    2250
# SR019    2250
# SR020    2250
# SR021    2250
# TN022    2250
# TN023    2250
# TN024    2250
# MS025    2250
# MS026    2250
# MS027    2250
# SS028    2250
# SS029    2250
# SS030    2250
# FW031    2250
# FW032    2250
# FW033    2250
# SR034    2250
# SR035    2250
# SR036    2250
# TN037    2250
# TN038    2250
# TN039    2250
# MS040    2250
# MS041    2250
# MS042    2250
# SS043    2250
# SS044    2250
# SS045    2250
# Name: count, dtype: int64
#
# === Value count: outlet_id ===
# outlet_id
# OUT-001    4050
# OUT-002    4050
# OUT-003    4050
# OUT-004    4050
# OUT-005    4050
# OUT-006    4050
# OUT-007    4050
# OUT-008    4050
# OUT-009    4050
# OUT-010    4050
# OUT-011    4050
# OUT-012    4050
# OUT-013    4050
# OUT-014    4050
# OUT-015    4050
# OUT-016    4050
# OUT-017    4050
# OUT-018    4050
# OUT-019    4050
# OUT-020    4050
# OUT-021    4050
# OUT-022    4050
# OUT-023    4050
# OUT-024    4050
# OUT-025    4050
# Name: count, dtype: int64
#
# === Value count: end_stock ===
# end_stock
# 0.0     33766
# NaN     33650
# 25.0     1216
# 16.0     1192
# 21.0     1190
# 4.0      1183
# 11.0     1179
# 8.0      1163
# 27.0     1161
# 9.0      1160
# 18.0     1155
# 10.0     1138
# 13.0     1135
# 23.0     1133
# 6.0      1127
# 26.0     1126
# 7.0      1119
# 29.0     1119
# 14.0     1118
# 20.0     1115
# 5.0      1114
# 2.0      1112
# 22.0     1112
# 15.0     1108
# 3.0      1106
# 28.0     1105
# 19.0     1091
# 12.0     1091
# 17.0     1084
# 1.0      1070
# 24.0     1062
# 30.0     1050
# Name: count, dtype: int64
#
# === Value count: stock_in ===
# stock_in
# 0.0     20486
# NaN     20471
# 5.0     20115
# 10.0    20094
# 15.0    20084
# Name: count, dtype: int64

# %%
df_inventory_outlet[df_inventory_outlet.isnull().any(axis=1)]
# Out:
#        snapshot_date sku_code outlet_id  end_stock  stock_in
# 1         2024-01-01    FW001   OUT-002        NaN      10.0
# 3         2024-01-01    FW001   OUT-004        NaN       NaN
# 4         2024-01-01    FW001   OUT-005        NaN       NaN
# 5         2024-01-01    FW001   OUT-006        NaN       NaN
# 6         2024-01-01    FW001   OUT-007        6.0       NaN
# ...              ...      ...       ...        ...       ...
# 101235    2024-03-30    SS045   OUT-011        NaN      10.0
# 101236    2024-03-30    SS045   OUT-012        NaN       NaN
# 101241    2024-03-30    SS045   OUT-017        0.0       NaN
# 101243    2024-03-30    SS045   OUT-019        0.0       NaN
# 101245    2024-03-30    SS045   OUT-021        NaN       5.0
#
# [47313 rows x 5 columns]

# %% [markdown]
# ##### CLEANING/TRANSFORM
